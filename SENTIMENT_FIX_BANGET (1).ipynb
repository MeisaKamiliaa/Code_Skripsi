# %%
import pandas as pd

df = pd.read_csv("ALL_SAHAM_RELEVANCY_NEWS.csv")
df
# Out:
#        Unnamed: 0     tanggal kategori  \
# 0               0  2022-01-05  ekonomi
# 1               1  2022-01-05  ekonomi
# 2               3  2022-01-05  ekonomi
# 3               4  2022-01-05  ekonomi
# 4               5  2022-01-05  ekonomi
# ...           ...         ...      ...
# 10643       16850  2024-12-31  ekonomi
# 10644       16851  2024-12-31  ekonomi
# 10645       16853  2024-12-31  ekonomi
# 10646       16854  2024-12-31  ekonomi
# 10647       16855  2024-12-31  ekonomi
#
#                                                    judul  \
# 0      Soroti Minyak Goreng Mahal, Ma'ruf Amin: Janga...
# 1      Lagi Terbelit Utang, Evergrande Disuruh Hancur...
# 2      Sri Mulyani Kasih Tugas Khusus ke Bos Baru LPE...
# 3      Perbankan Tak Bisa Mendadak Setop Biayai Batu ...
# 4      Harapan Jokowi Resmikan Pasar Johar: Ekonomi R...
# ...                                                  ...
# 10643  Hal tersebut disampaikan oleh Direktur Jendera...
# 10644  Menteri Keuangan Sri Mulyani Indrawati menjela...
# 10645  Kemendag mempunyai sembilan gudang SRG dan sat...
# 10646  Waspada Penipuan Mengatasnamakan Bea Cukai, In...
# 10647  Sejarah USD (Dolar AS) Jadi Patokan Mata Uang ...
#
#                                                      url  \
# 0      https://finance.detik.com/berita-ekonomi-bisni...
# 1      https://finance.detik.com/properti/d-5885844/l...
# 2      https://finance.detik.com/moneter/d-5885624/sr...
# 3      https://finance.detik.com/energi/d-5885790/per...
# 4      https://finance.detik.com/berita-ekonomi-bisni...
# ...                                                  ...
# 10643  https://finance.detik.com/energi/d-7712214/kad...
# 10644  https://finance.detik.com/berita-ekonomi-bisni...
# 10645  https://finance.detik.com/berita-ekonomi-bisni...
# 10646  https://finance.detik.com/berita-ekonomi-bisni...
# 10647  https://finance.detik.com/berita-ekonomi-bisni...
#
#                                             konten_clean
# 0      harga minyak goreng sorot publik  lantar harga...
# 1      selesai utang  kembang properti china evergran...
# 2      lembaga biaya ekspor indonesia  lpei  milik ke...
# 3      sektor uang perban arah dukung terap ekonomi h...
# 4      presiden joko widodo resmi pasar johar kota se...
# ...                                                  ...
# 10643  direktur jenderal ketenagalistrikan menteri en...
# 10644  menteri uang sri mulyani indrawati barang golo...
# 10645  kemendag sembilan gudang srg gudang sistem con...
# 10646  mei  zahra temu toko online instagram nama  or...
# 10647  zaman  emas patok mata uang anggap milik nilai...
#
# [10648 rows x 6 columns]

# %%
print(df["konten_clean"].head())
# Out:
# 0    harga minyak goreng sorot publik  lantar harga...
# 1    selesai utang  kembang properti china evergran...
# 2    lembaga biaya ekspor indonesia  lpei  milik ke...
# 3    sektor uang perban arah dukung terap ekonomi h...
# 4    presiden joko widodo resmi pasar johar kota se...
# Name: konten_clean, dtype: object

# %%
# Pilih model sentiment yang tersedia publik
model_name = "taufiqdp/indonesian-sentiment"

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification, pipeline

tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSequenceClassification.from_pretrained(model_name)

# %%
sentiment_pipe = pipeline("sentiment-analysis", model=model, tokenizer=tokenizer)
# Out:
# Device set to use cpu

# %%
def prediksi_sentimen(text):
    # agar tidak overflow, bisa dipotong (truncation) lewat pipeline sendiri
    try:
        res = sentiment_pipe(text)
        return res[0]["label"], res[0]["score"]
    except Exception as e:
        # fallback jika error
        return None, None

# %%
df["sentiment_label"], df["sentiment_score"] = zip(*df["konten_clean"].astype(str).map(prediksi_sentimen))

# %%
df[["konten_clean", "sentiment_label", "sentiment_score"]].head()
df.to_csv("ALL_SAHAM_RELEVANCY_NEWS_with_sentiment.csv", index=False)

# %%
df = pd.read_csv("ALL_SAHAM_RELEVANCY_NEWS.csv")
df
# Out:
#        Unnamed: 0     tanggal kategori  \
# 0               0  2022-01-05  ekonomi
# 1               1  2022-01-05  ekonomi
# 2               3  2022-01-05  ekonomi
# 3               4  2022-01-05  ekonomi
# 4               5  2022-01-05  ekonomi
# ...           ...         ...      ...
# 10643       16850  2024-12-31  ekonomi
# 10644       16851  2024-12-31  ekonomi
# 10645       16853  2024-12-31  ekonomi
# 10646       16854  2024-12-31  ekonomi
# 10647       16855  2024-12-31  ekonomi
#
#                                                    judul  \
# 0      Soroti Minyak Goreng Mahal, Ma'ruf Amin: Janga...
# 1      Lagi Terbelit Utang, Evergrande Disuruh Hancur...
# 2      Sri Mulyani Kasih Tugas Khusus ke Bos Baru LPE...
# 3      Perbankan Tak Bisa Mendadak Setop Biayai Batu ...
# 4      Harapan Jokowi Resmikan Pasar Johar: Ekonomi R...
# ...                                                  ...
# 10643  Hal tersebut disampaikan oleh Direktur Jendera...
# 10644  Menteri Keuangan Sri Mulyani Indrawati menjela...
# 10645  Kemendag mempunyai sembilan gudang SRG dan sat...
# 10646  Waspada Penipuan Mengatasnamakan Bea Cukai, In...
# 10647  Sejarah USD (Dolar AS) Jadi Patokan Mata Uang ...
#
#                                                      url  \
# 0      https://finance.detik.com/berita-ekonomi-bisni...
# 1      https://finance.detik.com/properti/d-5885844/l...
# 2      https://finance.detik.com/moneter/d-5885624/sr...
# 3      https://finance.detik.com/energi/d-5885790/per...
# 4      https://finance.detik.com/berita-ekonomi-bisni...
# ...                                                  ...
# 10643  https://finance.detik.com/energi/d-7712214/kad...
# 10644  https://finance.detik.com/berita-ekonomi-bisni...
# 10645  https://finance.detik.com/berita-ekonomi-bisni...
# 10646  https://finance.detik.com/berita-ekonomi-bisni...
# 10647  https://finance.detik.com/berita-ekonomi-bisni...
#
#                                             konten_clean
# 0      harga minyak goreng sorot publik  lantar harga...
# 1      selesai utang  kembang properti china evergran...
# 2      lembaga biaya ekspor indonesia  lpei  milik ke...
# 3      sektor uang perban arah dukung terap ekonomi h...
# 4      presiden joko widodo resmi pasar johar kota se...
# ...                                                  ...
# 10643  direktur jenderal ketenagalistrikan menteri en...
# 10644  menteri uang sri mulyani indrawati barang golo...
# 10645  kemendag sembilan gudang srg gudang sistem con...
# 10646  mei  zahra temu toko online instagram nama  or...
# 10647  zaman  emas patok mata uang anggap milik nilai...
#
# [10648 rows x 6 columns]

# %%
df=df.drop(columns=["Unnamed: 0"])
df.head()
# Out:
#       tanggal kategori                                              judul  \
# 0  2022-01-05  ekonomi  Soroti Minyak Goreng Mahal, Ma'ruf Amin: Janga...
# 1  2022-01-05  ekonomi  Lagi Terbelit Utang, Evergrande Disuruh Hancur...
# 2  2022-01-05  ekonomi  Sri Mulyani Kasih Tugas Khusus ke Bos Baru LPE...
# 3  2022-01-05  ekonomi  Perbankan Tak Bisa Mendadak Setop Biayai Batu ...
# 4  2022-01-05  ekonomi  Harapan Jokowi Resmikan Pasar Johar: Ekonomi R...
#
#                                                  url  \
# 0  https://finance.detik.com/berita-ekonomi-bisni...
# 1  https://finance.detik.com/properti/d-5885844/l...
# 2  https://finance.detik.com/moneter/d-5885624/sr...
# 3  https://finance.detik.com/energi/d-5885790/per...
# 4  https://finance.detik.com/berita-ekonomi-bisni...
#
#                                         konten_clean
# 0  harga minyak goreng sorot publik  lantar harga...
# 1  selesai utang  kembang properti china evergran...
# 2  lembaga biaya ekspor indonesia  lpei  milik ke...
# 3  sektor uang perban arah dukung terap ekonomi h...
# 4  presiden joko widodo resmi pasar johar kota se...

# %%
df.isna().sum()
# Out:
# tanggal         0
# kategori        0
# judul           0
# url             0
# konten_clean    0
# dtype: int64

# %%
# !pip install -q transformers torch pandas

import pandas as pd
import re
import torch
from transformers import pipeline, AutoTokenizer, AutoModelForSequenceClassification

# ========== 1. Load model & tokenizer yang benar ==========
MODEL_ID = "taufiqdp/indonesian-sentiment"  # ini model yang tersedia publik :contentReference[oaicite:1]{index=1}

tokenizer = AutoTokenizer.from_pretrained(MODEL_ID)
model = AutoModelForSequenceClassification.from_pretrained(MODEL_ID)

print("Label mapping (id2label):", model.config.id2label)

device = 0 if torch.cuda.is_available() else -1
sentiment_pipe = pipeline(
    "text-classification",
    model=model,
    tokenizer=tokenizer,
    device=device,
    return_all_scores=False
)
# Out:
# Device set to use cpu
# Label mapping (id2label): {0: 'negatif', 1: 'netral', 2: 'positif'}

# %%
# ========== 2. Fungsi batch prediksi ==========
def predict_batch(texts, batch_size=32):
    results = []
    for i in range(0, len(texts), batch_size):
        batch = texts[i : i + batch_size]
        preds = sentiment_pipe(batch, truncation=True, max_length=512)
        results.extend(preds)
    return results

# %%
# ========== 3. Keyword saham vs override ==========
positif_keywords = [
    "menguat", "rebound", "bullish", "surplus", "naik", "melonjak",
    "penguatan", "stabil", "optimis", "pulih", "rekor", "melambung"
]
negatif_keywords = [
    "melemah", "anjlok", "bearish", "defisit", "turun", "merosot",
    "penurunan", "tertekan", "resesi", "krisis", "minus", "collapse", "pelemahan"
]

positif_pattern = re.compile(r"\b(" + "|".join(positif_keywords) + r")\b", re.IGNORECASE)
negatif_pattern = re.compile(r"\b(" + "|".join(negatif_keywords) + r")\b", re.IGNORECASE)

def apply_keyword_override(text, model_label, model_score):
    pos_match = bool(positif_pattern.search(text))
    neg_match = bool(negatif_pattern.search(text))

    if pos_match and not neg_match:
        return "positif", 1.0
    elif neg_match and not pos_match:
        return "negatif", 1.0
    elif pos_match and neg_match:
        # kalau kedua jenis keyword ada, pilih berdasarkan jumlah kemunculan
        pos_count = len(positif_pattern.findall(text))
        neg_count = len(negatif_pattern.findall(text))
        if pos_count > neg_count:
            return "positif", 1.0
        elif neg_count > pos_count:
            return "negatif", 1.0
        else:
            # seimbang → fallback ke hasil model
            return model_label, model_score
    else:
        # tidak ada keyword → pake hasil model
        return model_label, model_score

# %%
# ========== 4. Proses DataFrame ==========
# Pastikan kamu punya DataFrame `df` dan ada kolom teks, misalnya “konten_clean”
df["konten_clean"] = df["konten_clean"].fillna("").astype(str)

preds = predict_batch(df["konten_clean"].tolist(), batch_size=32)
df["sentiment_label_model"] = [p["label"] for p in preds]
df["sentiment_score_model"] = [float(p["score"]) for p in preds]

# Model memberikan label default seperti "NEGATIVE", "NEUTRAL", "POSITIVE" atau tergantung id2label
# Kita bisa peta label ke bahasa Indonesia kalau ingin:
# Misal id2label = {0: "negative", 1: "neutral", 2: "positive"}
# Pastikan model.config.id2label terlebih dahulu

# Jika id2label mapping dalam bahasa Inggris, ubah ke bahasa Indonesia:
mapping = {}
for idx, lbl in model.config.id2label.items():
    lbl_low = lbl.lower()
    if "neg" in lbl_low:
        mapping[lbl] = "negatif"
    elif "neu" in lbl_low:
        mapping[lbl] = "netral"
    elif "pos" in lbl_low:
        mapping[lbl] = "positif"
    else:
        mapping[lbl] = lbl  # fallback

# Ubah label model ke versi Indonesia
df["sentiment_label_model_id"] = df["sentiment_label_model"].map(mapping).fillna(df["sentiment_label_model"])

# override keyword
adjusted = [
    apply_keyword_override(text, lbl_id, scr)
    for text, lbl_id, scr in zip(df["konten_clean"],
                                 df["sentiment_label_model_id"],
                                 df["sentiment_score_model"])
]
df["sentiment_label"], df["sentiment_score"] = zip(*adjusted)

# %%
# ========== 5. Simpan + cek distribusi ==========
df.to_csv("df_sentiment_saham_taufiqdp.csv", index=False)
print("Selesai — file ditulis: df_sentiment_saham_taufiqdp.csv")
print("Distribusi sentiment_label:", df["sentiment_label"].value_counts())
# Out:
# Selesai — file ditulis: df_sentiment_saham_taufiqdp.csv
# Distribusi sentiment_label: sentiment_label
# positif    4365
# netral     4174
# negatif    2109
# Name: count, dtype: int64

# %%
import pandas as pd
df = pd.read_csv("df_sentiment_saham_taufiqdp.csv")
df
# Out:
#           tanggal kategori                                              judul  \
# 0      2022-01-05  ekonomi  Soroti Minyak Goreng Mahal, Ma'ruf Amin: Janga...
# 1      2022-01-05  ekonomi  Lagi Terbelit Utang, Evergrande Disuruh Hancur...
# 2      2022-01-05  ekonomi  Sri Mulyani Kasih Tugas Khusus ke Bos Baru LPE...
# 3      2022-01-05  ekonomi  Perbankan Tak Bisa Mendadak Setop Biayai Batu ...
# 4      2022-01-05  ekonomi  Harapan Jokowi Resmikan Pasar Johar: Ekonomi R...
# ...           ...      ...                                                ...
# 10643  2024-12-31  ekonomi  Hal tersebut disampaikan oleh Direktur Jendera...
# 10644  2024-12-31  ekonomi  Menteri Keuangan Sri Mulyani Indrawati menjela...
# 10645  2024-12-31  ekonomi  Kemendag mempunyai sembilan gudang SRG dan sat...
# 10646  2024-12-31  ekonomi  Waspada Penipuan Mengatasnamakan Bea Cukai, In...
# 10647  2024-12-31  ekonomi  Sejarah USD (Dolar AS) Jadi Patokan Mata Uang ...
#
#                                                      url  \
# 0      https://finance.detik.com/berita-ekonomi-bisni...
# 1      https://finance.detik.com/properti/d-5885844/l...
# 2      https://finance.detik.com/moneter/d-5885624/sr...
# 3      https://finance.detik.com/energi/d-5885790/per...
# 4      https://finance.detik.com/berita-ekonomi-bisni...
# ...                                                  ...
# 10643  https://finance.detik.com/energi/d-7712214/kad...
# 10644  https://finance.detik.com/berita-ekonomi-bisni...
# 10645  https://finance.detik.com/berita-ekonomi-bisni...
# 10646  https://finance.detik.com/berita-ekonomi-bisni...
# 10647  https://finance.detik.com/berita-ekonomi-bisni...
#
#                                             konten_clean  \
# 0      harga minyak goreng sorot publik  lantar harga...
# 1      selesai utang  kembang properti china evergran...
# 2      lembaga biaya ekspor indonesia  lpei  milik ke...
# 3      sektor uang perban arah dukung terap ekonomi h...
# 4      presiden joko widodo resmi pasar johar kota se...
# ...                                                  ...
# 10643  direktur jenderal ketenagalistrikan menteri en...
# 10644  menteri uang sri mulyani indrawati barang golo...
# 10645  kemendag sembilan gudang srg gudang sistem con...
# 10646  mei  zahra temu toko online instagram nama  or...
# 10647  zaman  emas patok mata uang anggap milik nilai...
#
#       sentiment_label_model  sentiment_score_model sentiment_label_model_id  \
# 0                   negatif               0.956247                  negatif
# 1                    netral               0.656194                   netral
# 2                   positif               0.715069                  positif
# 3                   positif               0.878706                  positif
# 4                   positif               0.896946                  positif
# ...                     ...                    ...                      ...
# 10643                netral               0.931262                   netral
# 10644                netral               0.965333                   netral
# 10645                netral               0.612721                   netral
# 10646               negatif               0.940484                  negatif
# 10647                netral               0.484246                   netral
#
#       sentiment_label  sentiment_score
# 0             positif         1.000000
# 1             negatif         1.000000
# 2             positif         0.715069
# 3             negatif         1.000000
# 4             positif         0.896946
# ...               ...              ...
# 10643         positif         1.000000
# 10644         positif         1.000000
# 10645         positif         1.000000
# 10646         negatif         0.940484
# 10647         positif         1.000000
#
# [10648 rows x 10 columns]

# %%
df.isna().sum()
# Out:
# tanggal                     0
# kategori                    0
# judul                       0
# url                         0
# konten_clean                0
# sentiment_label_model       0
# sentiment_score_model       0
# sentiment_label_model_id    0
# sentiment_label             0
# sentiment_score             0
# dtype: int64

# %%
df.sentiment_label_model_id.value_counts()
# Out:
# sentiment_label_model_id
# netral     6534
# positif    3250
# negatif     864
# Name: count, dtype: int64

# %%
df.sentiment_label.value_counts()
# Out:
# sentiment_label
# positif    4365
# netral     4174
# negatif    2109
# Name: count, dtype: int64

# %%
import pandas as pd

df = pd.read_csv("df_sentiment_taufiqdp (1).csv")
df
# Out:
#        Unnamed: 0     tanggal kategori  \
# 0               0  2022-01-05  ekonomi
# 1               1  2022-01-05  ekonomi
# 2               3  2022-01-05  ekonomi
# 3               4  2022-01-05  ekonomi
# 4               5  2022-01-05  ekonomi
# ...           ...         ...      ...
# 10643       16850  2024-12-31  ekonomi
# 10644       16851  2024-12-31  ekonomi
# 10645       16853  2024-12-31  ekonomi
# 10646       16854  2024-12-31  ekonomi
# 10647       16855  2024-12-31  ekonomi
#
#                                                    judul  \
# 0      Soroti Minyak Goreng Mahal, Ma'ruf Amin: Janga...
# 1      Lagi Terbelit Utang, Evergrande Disuruh Hancur...
# 2      Sri Mulyani Kasih Tugas Khusus ke Bos Baru LPE...
# 3      Perbankan Tak Bisa Mendadak Setop Biayai Batu ...
# 4      Harapan Jokowi Resmikan Pasar Johar: Ekonomi R...
# ...                                                  ...
# 10643  Hal tersebut disampaikan oleh Direktur Jendera...
# 10644  Menteri Keuangan Sri Mulyani Indrawati menjela...
# 10645  Kemendag mempunyai sembilan gudang SRG dan sat...
# 10646  Waspada Penipuan Mengatasnamakan Bea Cukai, In...
# 10647  Sejarah USD (Dolar AS) Jadi Patokan Mata Uang ...
#
#                                                      url  \
# 0      https://finance.detik.com/berita-ekonomi-bisni...
# 1      https://finance.detik.com/properti/d-5885844/l...
# 2      https://finance.detik.com/moneter/d-5885624/sr...
# 3      https://finance.detik.com/energi/d-5885790/per...
# 4      https://finance.detik.com/berita-ekonomi-bisni...
# ...                                                  ...
# 10643  https://finance.detik.com/energi/d-7712214/kad...
# 10644  https://finance.detik.com/berita-ekonomi-bisni...
# 10645  https://finance.detik.com/berita-ekonomi-bisni...
# 10646  https://finance.detik.com/berita-ekonomi-bisni...
# 10647  https://finance.detik.com/berita-ekonomi-bisni...
#
#                                             konten_clean sentiment_label  \
# 0      harga minyak goreng sorot publik  lantar harga...         negatif
# 1      selesai utang  kembang properti china evergran...          netral
# 2      lembaga biaya ekspor indonesia  lpei  milik ke...         positif
# 3      sektor uang perban arah dukung terap ekonomi h...         positif
# 4      presiden joko widodo resmi pasar johar kota se...         positif
# ...                                                  ...             ...
# 10643  direktur jenderal ketenagalistrikan menteri en...          netral
# 10644  menteri uang sri mulyani indrawati barang golo...          netral
# 10645  kemendag sembilan gudang srg gudang sistem con...          netral
# 10646  mei  zahra temu toko online instagram nama  or...         negatif
# 10647  zaman  emas patok mata uang anggap milik nilai...          netral
#
#        sentiment_score
# 0             0.956247
# 1             0.656194
# 2             0.715069
# 3             0.878706
# 4             0.896946
# ...                ...
# 10643         0.931262
# 10644         0.965333
# 10645         0.612721
# 10646         0.940484
# 10647         0.484246
#
# [10648 rows x 8 columns]

# %%
df.sentiment_label.value_counts()
# Out:
# sentiment_label
# netral     6534
# positif    3250
# negatif     864
# Name: count, dtype: int64

# %%
df.isna().sum()
# Out:
# Unnamed: 0         0
# tanggal            0
# kategori           0
# judul              0
# url                0
# konten_clean       0
# sentiment_label    0
# sentiment_score    0
# dtype: int64

# %%
# Pilih hanya kolom yang penting
df_final = df[[
    "tanggal", "kategori", "judul", "url",
    "konten_clean", "sentiment_label", "sentiment_score"
]]

# Simpan ke CSV baru
df_final.to_csv("df_sentiment_saham_final.csv", index=False)
print("Selesai — hasil akhir disimpan ke df_sentiment_saham_final.csv")
print("Distribusi sentimen saham:")
print(df_final["sentiment_label"].value_counts())
# Out:
# Selesai — hasil akhir disimpan ke df_sentiment_saham_final.csv
# Distribusi sentimen saham:
# sentiment_label
# positif    4365
# netral     4174
# negatif    2109
# Name: count, dtype: int64

# %%
df_final = pd.read_csv("df_sentiment_saham_final.csv")
df_final
# Out:
#           tanggal kategori                                              judul  \
# 0      2022-01-05  ekonomi  Soroti Minyak Goreng Mahal, Ma'ruf Amin: Janga...
# 1      2022-01-05  ekonomi  Lagi Terbelit Utang, Evergrande Disuruh Hancur...
# 2      2022-01-05  ekonomi  Sri Mulyani Kasih Tugas Khusus ke Bos Baru LPE...
# 3      2022-01-05  ekonomi  Perbankan Tak Bisa Mendadak Setop Biayai Batu ...
# 4      2022-01-05  ekonomi  Harapan Jokowi Resmikan Pasar Johar: Ekonomi R...
# ...           ...      ...                                                ...
# 10643  2024-12-31  ekonomi  Hal tersebut disampaikan oleh Direktur Jendera...
# 10644  2024-12-31  ekonomi  Menteri Keuangan Sri Mulyani Indrawati menjela...
# 10645  2024-12-31  ekonomi  Kemendag mempunyai sembilan gudang SRG dan sat...
# 10646  2024-12-31  ekonomi  Waspada Penipuan Mengatasnamakan Bea Cukai, In...
# 10647  2024-12-31  ekonomi  Sejarah USD (Dolar AS) Jadi Patokan Mata Uang ...
#
#                                                      url  \
# 0      https://finance.detik.com/berita-ekonomi-bisni...
# 1      https://finance.detik.com/properti/d-5885844/l...
# 2      https://finance.detik.com/moneter/d-5885624/sr...
# 3      https://finance.detik.com/energi/d-5885790/per...
# 4      https://finance.detik.com/berita-ekonomi-bisni...
# ...                                                  ...
# 10643  https://finance.detik.com/energi/d-7712214/kad...
# 10644  https://finance.detik.com/berita-ekonomi-bisni...
# 10645  https://finance.detik.com/berita-ekonomi-bisni...
# 10646  https://finance.detik.com/berita-ekonomi-bisni...
# 10647  https://finance.detik.com/berita-ekonomi-bisni...
#
#                                             konten_clean sentiment_label  \
# 0      harga minyak goreng sorot publik  lantar harga...         positif
# 1      selesai utang  kembang properti china evergran...         negatif
# 2      lembaga biaya ekspor indonesia  lpei  milik ke...         positif
# 3      sektor uang perban arah dukung terap ekonomi h...         negatif
# 4      presiden joko widodo resmi pasar johar kota se...         positif
# ...                                                  ...             ...
# 10643  direktur jenderal ketenagalistrikan menteri en...         positif
# 10644  menteri uang sri mulyani indrawati barang golo...         positif
# 10645  kemendag sembilan gudang srg gudang sistem con...         positif
# 10646  mei  zahra temu toko online instagram nama  or...         negatif
# 10647  zaman  emas patok mata uang anggap milik nilai...         positif
#
#        sentiment_score
# 0             1.000000
# 1             1.000000
# 2             0.715069
# 3             1.000000
# 4             0.896946
# ...                ...
# 10643         1.000000
# 10644         1.000000
# 10645         1.000000
# 10646         0.940484
# 10647         1.000000
#
# [10648 rows x 7 columns]

# %%
df.sentiment_label.value_counts()
# Out:
# sentiment_label
# positif    4365
# netral     4174
# negatif    2109
# Name: count, dtype: int64

# %%
from sklearn.utils import resample

# Pisahkan per kelas
df_pos = df_final[df_final["sentiment_label"] == "positif"]
df_net = df_final[df_final["sentiment_label"] == "netral"]
df_neg = df_final[df_final["sentiment_label"] == "negatif"]

# Target jumlah
TARGET = 4000

# Resampling
df_pos_bal = resample(df_pos, replace=False, n_samples=TARGET, random_state=42)  # undersample
df_net_bal = resample(df_net, replace=False, n_samples=TARGET, random_state=42)  # undersample
df_neg_bal = resample(df_neg, replace=True,  n_samples=TARGET, random_state=42)  # oversample

# Gabung lagi
df_balanced = pd.concat([df_pos_bal, df_net_bal, df_neg_bal])

# Shuffle biar acak
df_balanced = df_balanced.sample(frac=1, random_state=42).reset_index(drop=True)

# Simpan
df_balanced.to_csv("df_sentiment_saham_balanced.csv", index=False)
print("Selesai — data balanced disimpan ke df_sentiment_saham_balanced.csv")
print("Distribusi baru:")
print(df_balanced["sentiment_label"].value_counts())
# Out:
# Selesai — data balanced disimpan ke df_sentiment_saham_balanced.csv
# Distribusi baru:
# sentiment_label
# positif    4000
# netral     4000
# negatif    4000
# Name: count, dtype: int64

# %%
df=pd.read_csv("df_sentiment_saham_balanced.csv")
df
# Out:
#           tanggal kategori                                              judul  \
# 0      2024-05-25  ekonomi  Ma, Beli Wajan di Transmart Full Day Sale Aja,...
# 1      2024-12-08  ekonomi  Di Transmart Full Day Sale, aneka sepeda listr...
# 2      2023-08-15  ekonomi  Gelaran Transmart Full Day Sale menjadi salah ...
# 3      2022-12-31  ekonomi  Pakar: Keputusan Bisnis Direksi BUMN dan Anak ...
# 4      2024-05-05  ekonomi  Banjir Diskon Transmart Full Day Sale! Aneka K...
# ...           ...      ...                                                ...
# 11995  2023-10-31  ekonomi  Jalan Panjang Pertamina Luncurkan Avtur Ramah ...
# 11996  2023-02-17  ekonomi  Stafsus Erick Thohir Ungkap Alasan Waskita Tun...
# 11997  2024-12-11  ekonomi  KPPU-Kementerian UMKM Bahas Pengawasan Kemitra...
# 11998  2023-09-27  ekonomi  BSI Duduki Peringkat Ke-3 ESG Rating Global Is...
# 11999  2024-04-09  ekonomi  Pengusaha Respons soal Barang Pekerja Migran y...
#
#                                                      url  \
# 0      https://finance.detik.com/berita-ekonomi-bisni...
# 1      https://finance.detik.com/berita-ekonomi-bisni...
# 2      https://finance.detik.com/berita-ekonomi-bisni...
# 3      https://finance.detik.com/detiktv/d-6491624/pa...
# 4      https://finance.detik.com/berita-ekonomi-bisni...
# ...                                                  ...
# 11995  https://finance.detik.com/energi/d-7012508/jal...
# 11996  https://finance.detik.com/bursa-dan-valas/d-65...
# 11997  https://finance.detik.com/berita-ekonomi-bisni...
# 11998  https://finance.detik.com/moneter/d-6954102/bs...
# 11999  https://finance.detik.com/berita-ekonomi-bisni...
#
#                                             konten_clean sentiment_label  \
# 0      pesta diskon transmart full day sale gelar bes...         positif
# 1      transmart full day sale  aneka sepeda listrik ...          netral
# 2      gelar transmart full day sale salah momen nant...         positif
# 3      solution advocacy institute selenggara giat we...         negatif
# 4      transmart full day sale hadir promo tarik butu...         positif
# ...                                                  ...             ...
# 11995  isu transisi energi gema iring target nol emis...         negatif
# 11996  staf khusus menteri bumn arya sinulingga buka ...          netral
# 11997  temu hasil urai strategi optimal mitra umkm  s...          netral
# 11998  pt bank syariah indonesia  bsi  konsisten impl...         positif
# 11999  usaha gabung himpun usaha muda indonesia  hipm...          netral
#
#        sentiment_score
# 0             0.974428
# 1             0.600188
# 2             0.806215
# 3             0.628222
# 4             0.848727
# ...                ...
# 11995         1.000000
# 11996         0.977572
# 11997         0.933186
# 11998         0.571682
# 11999         0.866349
#
# [12000 rows x 7 columns]

# %%
df.isna().sum()
# Out:
# tanggal            0
# kategori           0
# judul              0
# url                0
# konten_clean       0
# sentiment_label    0
# sentiment_score    0
# dtype: int64
